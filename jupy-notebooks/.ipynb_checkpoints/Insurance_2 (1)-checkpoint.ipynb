# %%
# to handle datasets
import pandas as pd
import numpy as np

# for plotting
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

# for encoding
from sklearn.preprocessing import OneHotEncoder, LabelEncoder,StandardScaler

# for the yeo-johnson transformation
import scipy.stats as stats
from sklearn.preprocessing import MinMaxScaler

# for model building
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier

# for checking model accuracy
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score

# to display all the columns of the dataframe in the notebook
pd.pandas.set_option('display.max_columns', None)

# %%
import os
ROOT_PATH = r"../data/train"


df_1 = pd.read_csv(os.path.join(ROOT_PATH,"Insurance_Claim_Info_data.csv"))
df_2 = pd.read_csv(os.path.join(ROOT_PATH, r"Insurance_Date_data.csv"))
df_3 = pd.read_csv(os.path.join(ROOT_PATH,"Insurance_Result_data.csv"))

# %%
combined = df_1.merge(df_2, left_on='Claim Number', right_on='Claim Number').merge(df_3,left_on='Claim Number', right_on='Claim Number')

# %%
# combined=pd.read_excel('Combined.xlsx')

# %%
combined.shape
# Out:
# (34110, 12)

# %%
combined['Disposition'].value_counts()
# Out:
# Disposition
# Deny               17848
# Approve in Full     9052
# Settle              7210
# Name: count, dtype: int64

# %%
# denied_df = combined[combined['Disposition']=='Deny'][:7210]
# approved_df = combined[combined['Disposition']=='Approve in Full'][:7210]
# settled_df = combined[combined['Disposition']=='Settle']
# final_df = pd.concat([settled_df,denied_df, approved_df],axis=0)
# final_df = final_df.sample(frac=1).reset_index(drop=True)
# final_df

# %%
# final_df['Product Insured'].value_counts()

# %%
sns.countplot(x = 'Disposition', data = combined)
# Out:
# <Axes: xlabel='Disposition', ylabel='count'>

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34110 entries, 0 to 34109
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Claim Number     34110 non-null  object
#  1   City Code        34110 non-null  object
#  2   City             34110 non-null  object
#  3   Enterprise Type  34110 non-null  object
#  4   Claim Type       34110 non-null  object
#  5   Claim Site       34110 non-null  object
#  6   Product Insured  34110 non-null  object
#  7   Incident Date    34110 non-null  object
#  8   Date Received    34110 non-null  object
#  9   Claim Amount     34110 non-null  float64
#  10  Close Amount     34110 non-null  float64
#  11  Disposition      34110 non-null  object
# dtypes: float64(2), object(10)
# memory usage: 3.1+ MB

# %%
# combined['Days Difference'] = (combined['Date Received'] - combined['Incident Date']).dt.days

# %%
combined
# Out:
#       Claim Number City Code       City             Enterprise Type
# 0       DQW1NZO0PL       NSK     Nashik      Public Limited Company  \
# 1       JS5GAPRN5B       BOM     Mumbai          One Person Company
# 2       ZTSVAQSEAQ       LKO    Lucknow      Public Limited Company
# 3       EW7NWHI7LI       DEL      Delhi         Sole Proprietorship
# 4       UJOFDC41EL       DEL      Delhi          One Person Company
# ...            ...       ...        ...                         ...
# 34105   5CFGWQ6IR5       AGR       Agra      Public Limited Company
# 34106   QQ6EAWA4Q5       LKO    Lucknow            Partnership Firm
# 34107   X1J58PT1J5       HYD  Hyderabad          One Person Company
# 34108   AGOXXE8KII       MAA    Chennai         Sole Proprietorship
# 34109   WT5RH23GPC       LKO    Lucknow  Private Ltd. MSME - Medium
#
#             Claim Type  Claim Site
# 0        Property Loss  In Transit  \
# 1        Property Loss  In Transit
# 2        Property Loss  In Transit
# 3        Property Loss  In Transit
# 4        Property Loss  In Transit
# ...                ...         ...
# 34105    Property Loss  In Transit
# 34106  Property Damage  In Transit
# 34107  Property Damage  In Transit
# 34108  Property Damage   Warehouse
# 34109    Property Loss  In Transit
#
#                                   Product Insured Incident Date Date Received
# 0                        Inventory - Raw Material    25-05-2007    06-07-2007  \
# 1      Cameras and other Misc. Security Equipment    17-09-2006    27-09-2006
# 2                                        Fixtures    12-06-2006    17-07-2006
# 3                                Pumps and Motors    13-11-2005    05-12-2005
# 4                         Misc. Engineering Tools    28-07-2008    12-08-2008
# ...                                           ...           ...           ...
# 34105                     Misc. Engineering Tools    19-12-2005    21-03-2006
# 34106                      Misc. Electronic Items    08-01-2007    16-01-2007
# 34107                      Misc. Electronic Items    19-09-2005    18-10-2005
# 34108                            Pumps and Motors    14-04-2009    09-09-2009
# 34109                    Inventory - Raw Material    19-03-2005    29-03-2005
#
#        Claim Amount  Close Amount      Disposition
# 0            490.00          0.00             Deny
# 1            300.00        150.00           Settle
# 2             83.98         83.98  Approve in Full
# 3            507.88          0.00             Deny
# 4             83.46         41.73           Settle
# ...             ...           ...              ...
# 34105        238.00        115.60           Settle
# 34106          7.00          0.00             Deny
# 34107        166.00         70.00           Settle
# 34108        450.00        280.00           Settle
# 34109         70.35         70.35  Approve in Full
#
# [34110 rows x 12 columns]

# %%
combined.isnull().sum()
# Out:
# Claim Number       0
# City Code          0
# City               0
# Enterprise Type    0
# Claim Type         0
# Claim Site         0
# Product Insured    0
# Incident Date      0
# Date Received      0
# Claim Amount       0
# Close Amount       0
# Disposition        0
# dtype: int64

# %%
# abs(final_df.apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1))

# %%
combined.drop([ 'Claim Number','Incident Date','Date Received'],axis=1,inplace=True)

# %%
combined.head()
# Out:
#   City Code     City         Enterprise Type     Claim Type  Claim Site
# 0       NSK   Nashik  Public Limited Company  Property Loss  In Transit  \
# 1       BOM   Mumbai      One Person Company  Property Loss  In Transit
# 2       LKO  Lucknow  Public Limited Company  Property Loss  In Transit
# 3       DEL    Delhi     Sole Proprietorship  Property Loss  In Transit
# 4       DEL    Delhi      One Person Company  Property Loss  In Transit
#
#                               Product Insured  Claim Amount  Close Amount
# 0                    Inventory - Raw Material        490.00          0.00  \
# 1  Cameras and other Misc. Security Equipment        300.00        150.00
# 2                                    Fixtures         83.98         83.98
# 3                            Pumps and Motors        507.88          0.00
# 4                     Misc. Engineering Tools         83.46         41.73
#
#        Disposition
# 0             Deny
# 1           Settle
# 2  Approve in Full
# 3             Deny
# 4           Settle

# %% [raw]
# {'Approve in Full': 2, 'Deny': 0, 'Settle': 1}

# %%
# final_df['Disposition'] = final_df['Disposition'].apply(lambda x: 0 if x == 'Deny' else (1 if x == 'Settle' else 2))
# final_df

# %%
combined['Disposition'] = combined['Disposition'].apply(lambda x: 0 if x == 'Deny' else (1 if x == 'Settle' else 2))
combined
# Out:
#       City Code       City             Enterprise Type       Claim Type
# 0           NSK     Nashik      Public Limited Company    Property Loss  \
# 1           BOM     Mumbai          One Person Company    Property Loss
# 2           LKO    Lucknow      Public Limited Company    Property Loss
# 3           DEL      Delhi         Sole Proprietorship    Property Loss
# 4           DEL      Delhi          One Person Company    Property Loss
# ...         ...        ...                         ...              ...
# 34105       AGR       Agra      Public Limited Company    Property Loss
# 34106       LKO    Lucknow            Partnership Firm  Property Damage
# 34107       HYD  Hyderabad          One Person Company  Property Damage
# 34108       MAA    Chennai         Sole Proprietorship  Property Damage
# 34109       LKO    Lucknow  Private Ltd. MSME - Medium    Property Loss
#
#        Claim Site                             Product Insured  Claim Amount
# 0      In Transit                    Inventory - Raw Material        490.00  \
# 1      In Transit  Cameras and other Misc. Security Equipment        300.00
# 2      In Transit                                    Fixtures         83.98
# 3      In Transit                            Pumps and Motors        507.88
# 4      In Transit                     Misc. Engineering Tools         83.46
# ...           ...                                         ...           ...
# 34105  In Transit                     Misc. Engineering Tools        238.00
# 34106  In Transit                      Misc. Electronic Items          7.00
# 34107  In Transit                      Misc. Electronic Items        166.00
# 34108   Warehouse                            Pumps and Motors        450.00
# 34109  In Transit                    Inventory - Raw Material         70.35
#
#        Close Amount  Disposition
# 0              0.00            0
# 1            150.00            1
# 2             83.98            2
# 3              0.00            0
# 4             41.73            1
# ...             ...          ...
# 34105        115.60            1
# 34106          0.00            0
# 34107         70.00            1
# 34108        280.00            1
# 34109         70.35            2
#
# [34110 rows x 9 columns]

# %%
combined
# Out:
#       City Code       City             Enterprise Type       Claim Type  \
# 0           NSK     Nashik      Public Limited Company    Property Loss
# 1           BOM     Mumbai          One Person Company    Property Loss
# 2           LKO    Lucknow      Public Limited Company    Property Loss
# 3           DEL      Delhi         Sole Proprietorship    Property Loss
# 4           DEL      Delhi          One Person Company    Property Loss
# ...         ...        ...                         ...              ...
# 34105       AGR       Agra      Public Limited Company    Property Loss
# 34106       LKO    Lucknow            Partnership Firm  Property Damage
# 34107       HYD  Hyderabad          One Person Company  Property Damage
# 34108       MAA    Chennai         Sole Proprietorship  Property Damage
# 34109       LKO    Lucknow  Private Ltd. MSME - Medium    Property Loss
#
#        Claim Site                             Product Insured  Claim Amount  \
# 0      In Transit                    Inventory - Raw Material        490.00
# 1      In Transit  Cameras and other Misc. Security Equipment        300.00
# 2      In Transit                                    Fixtures         83.98
# 3      In Transit                            Pumps and Motors        507.88
# 4      In Transit                     Misc. Engineering Tools         83.46
# ...           ...                                         ...           ...
# 34105  In Transit                     Misc. Engineering Tools        238.00
# 34106  In Transit                      Misc. Electronic Items          7.00
# 34107  In Transit                      Misc. Electronic Items        166.00
# 34108   Warehouse                            Pumps and Motors        450.00
# 34109  In Transit                    Inventory - Raw Material         70.35
#
#        Close Amount  Disposition
# 0              0.00            0
# 1            150.00            1
# 2             83.98            2
# 3              0.00            0
# 4             41.73            1
# ...             ...          ...
# 34105        115.60            1
# 34106          0.00            0
# 34107         70.00            1
# 34108        280.00            1
# 34109         70.35            2
#
# [34110 rows x 9 columns]

# %%
# final_df[final_df['Disposition']==0][['Enterprise Type', 'Claim Type', 'Claim Site']]

# %%
# final_df[final_df['Disposition']==0]['Enterprise Type'].value_counts()

# %%
# x = final_df.drop(['Disposition'], axis = 1)
# y = final_df['Disposition']

# %%
x = combined.drop(['Disposition'], axis = 1)
y = combined['Disposition']

# %%
x['Product Insured'].value_counts()
# Out:
# Inventory - Raw Material                                    8110
# Misc. Electronic Items                                      5611
# Misc. Engineering Tools                                     4247
# Inventory - Finished Goods                                  3322
# Furniture                                                   3034
# Misc. Electrical Equipment                                  2945
# Heating, ventilation, and air conditioning (HVAC) System    2787
# Fixtures                                                    1065
# Pumps and Motors                                            1025
# Misc. Lab Equipment                                          695
# Misc. Sensors                                                579
# Property, Plant, and Equipment (PPE) Parts                   347
# Cameras and other Misc. Security Equipment                   343
# Name: Product Insured, dtype: int64

# %%
y
# Out:
# 0        2
# 1        0
# 2        2
# 3        0
# 4        2
#         ..
# 21625    1
# 21626    2
# 21627    2
# 21628    0
# 21629    0
# Name: Disposition, Length: 21630, dtype: int64

# %%
cat_vars = ['City Code','City','Enterprise Type','Claim Type','Claim Site','Product Insured']

# %%
temp_df=pd.get_dummies(data=x, columns=cat_vars,drop_first=True)

# %%
temp_df_2 = pd.concat([temp_df, y],axis=1)

# %%
"Disposition" in temp_df_2.corr().index.values.tolist()
# Out:
# True

# %%
abs(temp_df_2.apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1))
# Out:
#                                                     Claim Amount  \
# Claim Amount                                            1.000000
# Close Amount                                            0.440843
# City Code_AMD                                           0.016747
# City Code_ATQ                                           0.014041
# City Code_BDQ                                           0.012993
# ...                                                          ...
# Product Insured_Misc. Lab Equipment                     0.063651
# Product Insured_Misc. Sensors                           0.005295
# Product Insured_Property, Plant, and Equipment ...      0.009255
# Product Insured_Pumps and Motors                        0.006790
# Disposition                                             0.022863
#
#                                                     Close Amount  \
# Claim Amount                                            0.440843
# Close Amount                                            1.000000
# City Code_AMD                                           0.033385
# City Code_ATQ                                           0.010285
# City Code_BDQ                                           0.001329
# ...                                                          ...
# Product Insured_Misc. Lab Equipment                     0.051034
# Product Insured_Misc. Sensors                           0.008161
# Product Insured_Property, Plant, and Equipment ...      0.015860
# Product Insured_Pumps and Motors                        0.050364
# Disposition                                             0.453405
#
#                                                     City Code_AMD  \
# Claim Amount                                             0.016747
# Close Amount                                             0.033385
# City Code_AMD                                            1.000000
# City Code_ATQ                                            0.037372
# City Code_BDQ                                            0.040029
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.003369
# Product Insured_Misc. Sensors                            0.004935
# Product Insured_Property, Plant, and Equipment ...       0.011824
# Product Insured_Pumps and Motors                         0.003831
# Disposition                                              0.043428
#
#                                                     City Code_ATQ  \
# Claim Amount                                             0.014041
# Close Amount                                             0.010285
# City Code_AMD                                            0.037372
# City Code_ATQ                                            1.000000
# City Code_BDQ                                            0.028663
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.000148
# Product Insured_Misc. Sensors                            0.001553
# Product Insured_Property, Plant, and Equipment ...       0.001914
# Product Insured_Pumps and Motors                         0.000770
# Disposition                                              0.032968
#
#                                                     City Code_BDQ  \
# Claim Amount                                             0.012993
# Close Amount                                             0.001329
# City Code_AMD                                            0.040029
# City Code_ATQ                                            0.028663
# City Code_BDQ                                            1.000000
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.005739
# Product Insured_Misc. Sensors                            0.009017
# Product Insured_Property, Plant, and Equipment ...       0.002296
# Product Insured_Pumps and Motors                         0.004515
# Disposition                                              0.001014
#
#                                                     City Code_BHO  \
# Claim Amount                                             0.001836
# Close Amount                                             0.002105
# City Code_AMD                                            0.042885
# City Code_ATQ                                            0.030707
# City Code_BDQ                                            0.032890
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.005328
# Product Insured_Misc. Sensors                            0.009647
# Product Insured_Property, Plant, and Equipment ...       0.002918
# Product Insured_Pumps and Motors                         0.004629
# Disposition                                              0.000074
#
#                                                     City Code_BLR  \
# Claim Amount                                             0.005178
# Close Amount                                             0.016331
# City Code_AMD                                            0.059416
# City Code_ATQ                                            0.042544
# City Code_BDQ                                            0.045569
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.003381
# Product Insured_Misc. Sensors                            0.011476
# Product Insured_Property, Plant, and Equipment ...       0.002418
# Product Insured_Pumps and Motors                         0.011235
# Disposition                                              0.000813
#
#                                                     City Code_BOM  \
# Claim Amount                                             0.017024
# Close Amount                                             0.001479
# City Code_AMD                                            0.065104
# City Code_ATQ                                            0.046617
# City Code_BDQ                                            0.049932
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.020311
# Product Insured_Misc. Sensors                            0.001282
# Product Insured_Property, Plant, and Equipment ...       0.013232
# Product Insured_Pumps and Motors                         0.006507
# Disposition                                              0.021772
#
#                                                     City Code_CCU  \
# Claim Amount                                             0.008319
# Close Amount                                             0.010199
# City Code_AMD                                            0.050399
# City Code_ATQ                                            0.036088
# City Code_BDQ                                            0.038654
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.006169
# Product Insured_Misc. Sensors                            0.002018
# Product Insured_Property, Plant, and Equipment ...       0.004311
# Product Insured_Pumps and Motors                         0.018310
# Disposition                                              0.008985
#
#                                                     City Code_CJB  \
# Claim Amount                                             0.008776
# Close Amount                                             0.005003
# City Code_AMD                                            0.043662
# City Code_ATQ                                            0.031264
# City Code_BDQ                                            0.033487
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.003929
# Product Insured_Misc. Sensors                            0.014036
# Product Insured_Property, Plant, and Equipment ...       0.000361
# Product Insured_Pumps and Motors                         0.003614
# Disposition                                              0.025439
#
#                                                     City Code_DEL  \
# Claim Amount                                             0.011018
# Close Amount                                             0.005374
# City Code_AMD                                            0.062229
# City Code_ATQ                                            0.044559
# City Code_BDQ                                            0.047727
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.007368
# Product Insured_Misc. Sensors                            0.007153
# Product Insured_Property, Plant, and Equipment ...       0.003419
# Product Insured_Pumps and Motors                         0.016793
# Disposition                                              0.004428
#
#                                                     City Code_HYD  \
# Claim Amount                                             0.004332
# Close Amount                                             0.023598
# City Code_AMD                                            0.058338
# City Code_ATQ                                            0.041772
# City Code_BDQ                                            0.044742
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.002126
# Product Insured_Misc. Sensors                            0.013782
# Product Insured_Property, Plant, and Equipment ...       0.000925
# Product Insured_Pumps and Motors                         0.009845
# Disposition                                              0.048580
#
#                                                     City Code_IDR  \
# Claim Amount                                             0.006067
# Close Amount                                             0.002533
# City Code_AMD                                            0.044872
# City Code_ATQ                                            0.032130
# City Code_BDQ                                            0.034414
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.003089
# Product Insured_Misc. Sensors                            0.000608
# Product Insured_Property, Plant, and Equipment ...       0.000171
# Product Insured_Pumps and Motors                         0.000066
# Disposition                                              0.017462
#
#                                                     City Code_JAI  \
# Claim Amount                                             0.001900
# Close Amount                                             0.028253
# City Code_AMD                                            0.047702
# City Code_ATQ                                            0.034157
# City Code_BDQ                                            0.036585
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.016558
# Product Insured_Misc. Sensors                            0.009995
# Product Insured_Property, Plant, and Equipment ...       0.010946
# Product Insured_Pumps and Motors                         0.033626
# Disposition                                              0.039061
#
#                                                     City Code_KNU  \
# Claim Amount                                             0.000756
# Close Amount                                             0.005458
# City Code_AMD                                            0.046431
# City Code_ATQ                                            0.033246
# City Code_BDQ                                            0.035610
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.007902
# Product Insured_Misc. Sensors                            0.003527
# Product Insured_Property, Plant, and Equipment ...       0.003347
# Product Insured_Pumps and Motors                         0.009377
# Disposition                                              0.015184
#
#                                                     City Code_LKO  \
# Claim Amount                                             0.001086
# Close Amount                                             0.002088
# City Code_AMD                                            0.051442
# City Code_ATQ                                            0.036835
# City Code_BDQ                                            0.039454
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.010203
# Product Insured_Misc. Sensors                            0.004173
# Product Insured_Property, Plant, and Equipment ...       0.000348
# Product Insured_Pumps and Motors                         0.009245
# Disposition                                              0.026797
#
#                                                     City Code_MAA  \
# Claim Amount                                             0.000747
# Close Amount                                             0.010731
# City Code_AMD                                            0.053016
# City Code_ATQ                                            0.037961
# City Code_BDQ                                            0.040660
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.000484
# Product Insured_Misc. Sensors                            0.000605
# Product Insured_Property, Plant, and Equipment ...       0.004951
# Product Insured_Pumps and Motors                         0.009844
# Disposition                                              0.018570
#
#                                                     City Code_NGP  \
# Claim Amount                                             0.000155
# Close Amount                                             0.005757
# City Code_AMD                                            0.046395
# City Code_ATQ                                            0.033221
# City Code_BDQ                                            0.035582
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.004759
# Product Insured_Misc. Sensors                            0.004733
# Product Insured_Property, Plant, and Equipment ...       0.005608
# Product Insured_Pumps and Motors                         0.000355
# Disposition                                              0.000952
#
#                                                     City Code_NSK  \
# Claim Amount                                             0.004363
# Close Amount                                             0.006075
# City Code_AMD                                            0.039785
# City Code_ATQ                                            0.028488
# City Code_BDQ                                            0.030513
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.006699
# Product Insured_Misc. Sensors                            0.001286
# Product Insured_Property, Plant, and Equipment ...       0.002098
# Product Insured_Pumps and Motors                         0.013380
# Disposition                                              0.014104
#
#                                                     City Code_PAT  \
# Claim Amount                                             0.004016
# Close Amount                                             0.006111
# City Code_AMD                                            0.041469
# City Code_ATQ                                            0.029693
# City Code_BDQ                                            0.031804
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.015550
# Product Insured_Misc. Sensors                            0.008354
# Product Insured_Property, Plant, and Equipment ...       0.008426
# Product Insured_Pumps and Motors                         0.009473
# Disposition                                              0.003816
#
#                                                     City Code_PNQ  \
# Claim Amount                                             0.009961
# Close Amount                                             0.001426
# City Code_AMD                                            0.052404
# City Code_ATQ                                            0.037523
# City Code_BDQ                                            0.040191
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.008322
# Product Insured_Misc. Sensors                            0.011517
# Product Insured_Property, Plant, and Equipment ...       0.008922
# Product Insured_Pumps and Motors                         0.006907
# Disposition                                              0.008918
#
#                                                     City Code_STV  \
# Claim Amount                                             0.007689
# Close Amount                                             0.005215
# City Code_AMD                                            0.049271
# City Code_ATQ                                            0.035280
# City Code_BDQ                                            0.037788
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.012195
# Product Insured_Misc. Sensors                            0.002496
# Product Insured_Property, Plant, and Equipment ...       0.002237
# Product Insured_Pumps and Motors                         0.007129
# Disposition                                              0.001518
#
#                                                     City Code_THN  \
# Claim Amount                                             0.000842
# Close Amount                                             0.006993
# City Code_AMD                                            0.043285
# City Code_ATQ                                            0.030993
# City Code_BDQ                                            0.033197
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.006902
# Product Insured_Misc. Sensors                            0.005043
# Product Insured_Property, Plant, and Equipment ...       0.006429
# Product Insured_Pumps and Motors                         0.016413
# Disposition                                              0.007771
#
#                                                     City Code_VSK  \
# Claim Amount                                             0.001506
# Close Amount                                             0.002833
# City Code_AMD                                            0.041390
# City Code_ATQ                                            0.029637
# City Code_BDQ                                            0.031744
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.005812
# Product Insured_Misc. Sensors                            0.006987
# Product Insured_Property, Plant, and Equipment ...       0.006708
# Product Insured_Pumps and Motors                         0.005312
# Disposition                                              0.012692
#
#                                                     City_Ahmedabad  \
# Claim Amount                                              0.016747
# Close Amount                                              0.033385
# City Code_AMD                                             1.000000
# City Code_ATQ                                             0.037372
# City Code_BDQ                                             0.040029
# ...                                                            ...
# Product Insured_Misc. Lab Equipment                       0.003369
# Product Insured_Misc. Sensors                             0.004935
# Product Insured_Property, Plant, and Equipment ...        0.011824
# Product Insured_Pumps and Motors                          0.003831
# Disposition                                               0.043428
#
#                                                     City_Amritsar  \
# Claim Amount                                             0.014041
# Close Amount                                             0.010285
# City Code_AMD                                            0.037372
# City Code_ATQ                                            1.000000
# City Code_BDQ                                            0.028663
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.000148
# Product Insured_Misc. Sensors                            0.001553
# Product Insured_Property, Plant, and Equipment ...       0.001914
# Product Insured_Pumps and Motors                         0.000770
# Disposition                                              0.032968
#
#                                                     City_Bangalore  \
# Claim Amount                                              0.005178
# Close Amount                                              0.016331
# City Code_AMD                                             0.059416
# City Code_ATQ                                             0.042544
# City Code_BDQ                                             0.045569
# ...                                                            ...
# Product Insured_Misc. Lab Equipment                       0.003381
# Product Insured_Misc. Sensors                             0.011476
# Product Insured_Property, Plant, and Equipment ...        0.002418
# Product Insured_Pumps and Motors                          0.011235
# Disposition                                               0.000813
#
#                                                     City_Bhopal  City_Chennai  \
# Claim Amount                                           0.001836      0.000747
# Close Amount                                           0.002105      0.010731
# City Code_AMD                                          0.042885      0.053016
# City Code_ATQ                                          0.030707      0.037961
# City Code_BDQ                                          0.032890      0.040660
# ...                                                         ...           ...
# Product Insured_Misc. Lab Equipment                    0.005328      0.000484
# Product Insured_Misc. Sensors                          0.009647      0.000605
# Product Insured_Property, Plant, and Equipment ...     0.002918      0.004951
# Product Insured_Pumps and Motors                       0.004629      0.009844
# Disposition                                            0.000074      0.018570
#
#                                                     City_Coimbatore  \
# Claim Amount                                               0.008776
# Close Amount                                               0.005003
# City Code_AMD                                              0.043662
# City Code_ATQ                                              0.031264
# City Code_BDQ                                              0.033487
# ...                                                             ...
# Product Insured_Misc. Lab Equipment                        0.003929
# Product Insured_Misc. Sensors                              0.014036
# Product Insured_Property, Plant, and Equipment ...         0.000361
# Product Insured_Pumps and Motors                           0.003614
# Disposition                                                0.025439
#
#                                                     City_Delhi  \
# Claim Amount                                          0.011018
# Close Amount                                          0.005374
# City Code_AMD                                         0.062229
# City Code_ATQ                                         0.044559
# City Code_BDQ                                         0.047727
# ...                                                        ...
# Product Insured_Misc. Lab Equipment                   0.007368
# Product Insured_Misc. Sensors                         0.007153
# Product Insured_Property, Plant, and Equipment ...    0.003419
# Product Insured_Pumps and Motors                      0.016793
# Disposition                                           0.004428
#
#                                                     City_Hyderabad  \
# Claim Amount                                              0.004332
# Close Amount                                              0.023598
# City Code_AMD                                             0.058338
# City Code_ATQ                                             0.041772
# City Code_BDQ                                             0.044742
# ...                                                            ...
# Product Insured_Misc. Lab Equipment                       0.002126
# Product Insured_Misc. Sensors                             0.013782
# Product Insured_Property, Plant, and Equipment ...        0.000925
# Product Insured_Pumps and Motors                          0.009845
# Disposition                                               0.048580
#
#                                                     City_Indore  City_Jaipur  \
# Claim Amount                                           0.006067     0.001900
# Close Amount                                           0.002533     0.028253
# City Code_AMD                                          0.044872     0.047702
# City Code_ATQ                                          0.032130     0.034157
# City Code_BDQ                                          0.034414     0.036585
# ...                                                         ...          ...
# Product Insured_Misc. Lab Equipment                    0.003089     0.016558
# Product Insured_Misc. Sensors                          0.000608     0.009995
# Product Insured_Property, Plant, and Equipment ...     0.000171     0.010946
# Product Insured_Pumps and Motors                       0.000066     0.033626
# Disposition                                            0.017462     0.039061
#
#                                                     City_Kanpur  City_Kolkata  \
# Claim Amount                                           0.000756      0.008319
# Close Amount                                           0.005458      0.010199
# City Code_AMD                                          0.046431      0.050399
# City Code_ATQ                                          0.033246      0.036088
# City Code_BDQ                                          0.035610      0.038654
# ...                                                         ...           ...
# Product Insured_Misc. Lab Equipment                    0.007902      0.006169
# Product Insured_Misc. Sensors                          0.003527      0.002018
# Product Insured_Property, Plant, and Equipment ...     0.003347      0.004311
# Product Insured_Pumps and Motors                       0.009377      0.018310
# Disposition                                            0.015184      0.008985
#
#                                                     City_Lucknow  City_Mumbai  \
# Claim Amount                                            0.001086     0.017024
# Close Amount                                            0.002088     0.001479
# City Code_AMD                                           0.051442     0.065104
# City Code_ATQ                                           0.036835     0.046617
# City Code_BDQ                                           0.039454     0.049932
# ...                                                          ...          ...
# Product Insured_Misc. Lab Equipment                     0.010203     0.020311
# Product Insured_Misc. Sensors                           0.004173     0.001282
# Product Insured_Property, Plant, and Equipment ...      0.000348     0.013232
# Product Insured_Pumps and Motors                        0.009245     0.006507
# Disposition                                             0.026797     0.021772
#
#                                                     City_Nagpur  City_Nashik  \
# Claim Amount                                           0.000155     0.004363
# Close Amount                                           0.005757     0.006075
# City Code_AMD                                          0.046395     0.039785
# City Code_ATQ                                          0.033221     0.028488
# City Code_BDQ                                          0.035582     0.030513
# ...                                                         ...          ...
# Product Insured_Misc. Lab Equipment                    0.004759     0.006699
# Product Insured_Misc. Sensors                          0.004733     0.001286
# Product Insured_Property, Plant, and Equipment ...     0.005608     0.002098
# Product Insured_Pumps and Motors                       0.000355     0.013380
# Disposition                                            0.000952     0.014104
#
#                                                     City_Patna  City_Pune  \
# Claim Amount                                          0.004016   0.009961
# Close Amount                                          0.006111   0.001426
# City Code_AMD                                         0.041469   0.052404
# City Code_ATQ                                         0.029693   0.037523
# City Code_BDQ                                         0.031804   0.040191
# ...                                                        ...        ...
# Product Insured_Misc. Lab Equipment                   0.015550   0.008322
# Product Insured_Misc. Sensors                         0.008354   0.011517
# Product Insured_Property, Plant, and Equipment ...    0.008426   0.008922
# Product Insured_Pumps and Motors                      0.009473   0.006907
# Disposition                                           0.003816   0.008918
#
#                                                     City_Surat  City_Thane  \
# Claim Amount                                          0.007689    0.000842
# Close Amount                                          0.005215    0.006993
# City Code_AMD                                         0.049271    0.043285
# City Code_ATQ                                         0.035280    0.030993
# City Code_BDQ                                         0.037788    0.033197
# ...                                                        ...         ...
# Product Insured_Misc. Lab Equipment                   0.012195    0.006902
# Product Insured_Misc. Sensors                         0.002496    0.005043
# Product Insured_Property, Plant, and Equipment ...    0.002237    0.006429
# Product Insured_Pumps and Motors                      0.007129    0.016413
# Disposition                                           0.001518    0.007771
#
#                                                     City_Vadodara  \
# Claim Amount                                             0.012993
# Close Amount                                             0.001329
# City Code_AMD                                            0.040029
# City Code_ATQ                                            0.028663
# City Code_BDQ                                            1.000000
# ...                                                           ...
# Product Insured_Misc. Lab Equipment                      0.005739
# Product Insured_Misc. Sensors                            0.009017
# Product Insured_Property, Plant, and Equipment ...       0.002296
# Product Insured_Pumps and Motors                         0.004515
# Disposition                                              0.001014
#
#                                                     City_Visakhapatnam  \
# Claim Amount                                                  0.001506
# Close Amount                                                  0.002833
# City Code_AMD                                                 0.041390
# City Code_ATQ                                                 0.029637
# City Code_BDQ                                                 0.031744
# ...                                                                ...
# Product Insured_Misc. Lab Equipment                           0.005812
# Product Insured_Misc. Sensors                                 0.006987
# Product Insured_Property, Plant, and Equipment ...            0.006708
# Product Insured_Pumps and Motors                              0.005312
# Disposition                                                   0.012692
#
#                                                     Enterprise Type_Foreign Subsidary  \
# Claim Amount                                                                 0.003518
# Close Amount                                                                 0.025814
# City Code_AMD                                                                0.037280
# City Code_ATQ                                                                0.037023
# City Code_BDQ                                                                0.050061
# ...                                                                               ...
# Product Insured_Misc. Lab Equipment                                          0.005652
# Product Insured_Misc. Sensors                                                0.013481
# Product Insured_Property, Plant, and Equipment ...                           0.005554
# Product Insured_Pumps and Motors                                             0.003236
# Disposition                                                                  0.041570
#
#                                                     Enterprise Type_Joint-Venture Company  \
# Claim Amount                                                                     0.000647
# Close Amount                                                                     0.000663
# City Code_AMD                                                                    0.009749
# City Code_ATQ                                                                    0.017011
# City Code_BDQ                                                                    0.021654
# ...                                                                                   ...
# Product Insured_Misc. Lab Equipment                                              0.003644
# Product Insured_Misc. Sensors                                                    0.018543
# Product Insured_Property, Plant, and Equipment ...                               0.010621
# Product Insured_Pumps and Motors                                                 0.002480
# Disposition                                                                      0.020532
#
#                                                     Enterprise Type_Limited Liability Parterneship (LLP)  \
# Claim Amount                                                                                 0.000790
# Close Amount                                                                                 0.000247
# City Code_AMD                                                                                0.027158
# City Code_ATQ                                                                                0.047869
# City Code_BDQ                                                                                0.007170
# ...                                                                                               ...
# Product Insured_Misc. Lab Equipment                                                          0.002068
# Product Insured_Misc. Sensors                                                                0.006486
# Product Insured_Property, Plant, and Equipment ...                                           0.004281
# Product Insured_Pumps and Motors                                                             0.011283
# Disposition                                                                                  0.004910
#
#                                                     Enterprise Type_Non-Profit Organization (NPO)  \
# Claim Amount                                                                             0.015501
# Close Amount                                                                             0.012797
# City Code_AMD                                                                            0.044752
# City Code_ATQ                                                                            0.005485
# City Code_BDQ                                                                            0.037748
# ...                                                                                           ...
# Product Insured_Misc. Lab Equipment                                                      0.000576
# Product Insured_Misc. Sensors                                                            0.009595
# Product Insured_Property, Plant, and Equipment ...                                       0.005786
# Product Insured_Pumps and Motors                                                         0.011311
# Disposition                                                                              0.006416
#
#                                                     Enterprise Type_One Person Company  \
# Claim Amount                                                                  0.010439
# Close Amount                                                                  0.003799
# City Code_AMD                                                                 0.025216
# City Code_ATQ                                                                 0.028814
# City Code_BDQ                                                                 0.000614
# ...                                                                                ...
# Product Insured_Misc. Lab Equipment                                           0.007710
# Product Insured_Misc. Sensors                                                 0.000424
# Product Insured_Property, Plant, and Equipment ...                            0.006616
# Product Insured_Pumps and Motors                                              0.012007
# Disposition                                                                   0.002737
#
#                                                     Enterprise Type_Partnership Firm  \
# Claim Amount                                                                0.012390
# Close Amount                                                                0.004481
# City Code_AMD                                                               0.003313
# City Code_ATQ                                                               0.215223
# City Code_BDQ                                                               0.051535
# ...                                                                              ...
# Product Insured_Misc. Lab Equipment                                         0.020418
# Product Insured_Misc. Sensors                                               0.003144
# Product Insured_Property, Plant, and Equipment ...                          0.003310
# Product Insured_Pumps and Motors                                            0.024074
# Disposition                                                                 0.012097
#
#                                                     Enterprise Type_Private Limited Company  \
# Claim Amount                                                                       0.004254
# Close Amount                                                                       0.001980
# City Code_AMD                                                                      0.035244
# City Code_ATQ                                                                      0.012428
# City Code_BDQ                                                                      0.032959
# ...                                                                                     ...
# Product Insured_Misc. Lab Equipment                                                0.001268
# Product Insured_Misc. Sensors                                                      0.006354
# Product Insured_Property, Plant, and Equipment ...                                 0.001672
# Product Insured_Pumps and Motors                                                   0.007535
# Disposition                                                                        0.007340
#
#                                                     Enterprise Type_Private Ltd. MSME - Medium  \
# Claim Amount                                                                          0.005479
# Close Amount                                                                          0.017807
# City Code_AMD                                                                         0.016847
# City Code_ATQ                                                                         0.009713
# City Code_BDQ                                                                         0.011664
# ...                                                                                        ...
# Product Insured_Misc. Lab Equipment                                                   0.000216
# Product Insured_Misc. Sensors                                                         0.004913
# Product Insured_Property, Plant, and Equipment ...                                    0.003085
# Product Insured_Pumps and Motors                                                      0.003300
# Disposition                                                                           0.039090
#
#                                                     Enterprise Type_Private Ltd. MSME - Micro  \
# Claim Amount                                                                         0.018416
# Close Amount                                                                         0.019686
# City Code_AMD                                                                        0.438052
# City Code_ATQ                                                                        0.034307
# City Code_BDQ                                                                        0.024727
# ...                                                                                       ...
# Product Insured_Misc. Lab Equipment                                                  0.002354
# Product Insured_Misc. Sensors                                                        0.001573
# Product Insured_Property, Plant, and Equipment ...                                   0.007827
# Product Insured_Pumps and Motors                                                     0.001010
# Disposition                                                                          0.022251
#
#                                                     Enterprise Type_Private Ltd. MSME - Small  \
# Claim Amount                                                                         0.004838
# Close Amount                                                                         0.007735
# City Code_AMD                                                                        0.001372
# City Code_ATQ                                                                        0.011960
# City Code_BDQ                                                                        0.019657
# ...                                                                                       ...
# Product Insured_Misc. Lab Equipment                                                  0.010385
# Product Insured_Misc. Sensors                                                        0.000542
# Product Insured_Property, Plant, and Equipment ...                                   0.004833
# Product Insured_Pumps and Motors                                                     0.013500
# Disposition                                                                          0.004113
#
#                                                     Enterprise Type_Public Limited Company  \
# Claim Amount                                                                      0.007025
# Close Amount                                                                      0.002024
# City Code_AMD                                                                     0.047339
# City Code_ATQ                                                                     0.036257
# City Code_BDQ                                                                     0.040770
# ...                                                                                    ...
# Product Insured_Misc. Lab Equipment                                               0.003569
# Product Insured_Misc. Sensors                                                     0.004098
# Product Insured_Property, Plant, and Equipment ...                                0.006695
# Product Insured_Pumps and Motors                                                  0.006627
# Disposition                                                                       0.019132
#
#                                                     Enterprise Type_Sole Proprietorship  \
# Claim Amount                                                                   0.008165
# Close Amount                                                                   0.010010
# City Code_AMD                                                                  0.060513
# City Code_ATQ                                                                  0.044272
# City Code_BDQ                                                                  0.028768
# ...                                                                                 ...
# Product Insured_Misc. Lab Equipment                                            0.004036
# Product Insured_Misc. Sensors                                                  0.002488
# Product Insured_Property, Plant, and Equipment ...                             0.001757
# Product Insured_Pumps and Motors                                               0.014233
# Disposition                                                                    0.006419
#
#                                                     Claim Type_Property Loss  \
# Claim Amount                                                        0.083305
# Close Amount                                                        0.023452
# City Code_AMD                                                       0.000445
# City Code_ATQ                                                       0.017057
# City Code_BDQ                                                       0.001089
# ...                                                                      ...
# Product Insured_Misc. Lab Equipment                                 0.109007
# Product Insured_Misc. Sensors                                       0.047212
# Product Insured_Property, Plant, and Equipment ...                  0.032036
# Product Insured_Pumps and Motors                                    0.010434
# Disposition                                                         0.071504
#
# ...
# ...                                                              ...
# Product Insured_Misc. Lab Equipment                         0.017571
# Product Insured_Misc. Sensors                               0.003419
# Product Insured_Property, Plant, and Equipment ...          0.000563
# Product Insured_Pumps and Motors                            0.003881
# Disposition                                                 0.010326
#
#                                                     Claim Site_Warehouse  \
# Claim Amount                                                    0.007665
# Close Amount                                                    0.052562
# City Code_AMD                                                   0.019050
# City Code_ATQ                                                   0.007991
# City Code_BDQ                                                   0.050042
# ...                                                                  ...
# Product Insured_Misc. Lab Equipment                             0.078052
# Product Insured_Misc. Sensors                                   0.114210
# Product Insured_Property, Plant, and Equipment ...              0.013133
# Product Insured_Pumps and Motors                                0.152880
# Disposition                                                     0.067272
#
#                                                     Product Insured_Fixtures  \
# Claim Amount                                                        0.031166
# Close Amount                                                        0.003449
# City Code_AMD                                                       0.002972
# City Code_ATQ                                                       0.002917
# City Code_BDQ                                                       0.002259
# ...                                                                      ...
# Product Insured_Misc. Lab Equipment                                 0.025891
# Product Insured_Misc. Sensors                                       0.023591
# Product Insured_Property, Plant, and Equipment ...                  0.018200
# Product Insured_Pumps and Motors                                    0.031599
# Disposition                                                         0.032406
#
#                                                     Product Insured_Furniture  \
# Claim Amount                                                         0.096026
# Close Amount                                                         0.026871
# City Code_AMD                                                        0.005454
# City Code_ATQ                                                        0.010294
# City Code_BDQ                                                        0.040365
# ...                                                                       ...
# Product Insured_Misc. Lab Equipment                                  0.045063
# Product Insured_Misc. Sensors                                        0.041059
# Product Insured_Property, Plant, and Equipment ...                   0.031677
# Product Insured_Pumps and Motors                                     0.054997
# Disposition                                                          0.114480
#
#                                                     Product Insured_Heating, ventilation, and air conditioning (HVAC) System  \
# Claim Amount                                                                                 0.028123
# Close Amount                                                                                 0.026957
# City Code_AMD                                                                                0.008995
# City Code_ATQ                                                                                0.001100
# City Code_BDQ                                                                                0.008176
# ...                                                                                               ...
# Product Insured_Misc. Lab Equipment                                                          0.043019
# Product Insured_Misc. Sensors                                                                0.039197
# Product Insured_Property, Plant, and Equipment ...                                           0.030240
# Product Insured_Pumps and Motors                                                             0.052503
# Disposition                                                                                  0.083165
#
#                                                     Product Insured_Inventory - Finished Goods  \
# Claim Amount                                                                          0.040013
# Close Amount                                                                          0.007221
# City Code_AMD                                                                         0.011938
# City Code_ATQ                                                                         0.007708
# City Code_BDQ                                                                         0.008114
# ...                                                                                        ...
# Product Insured_Misc. Lab Equipment                                                   0.047373
# Product Insured_Misc. Sensors                                                         0.043164
# Product Insured_Property, Plant, and Equipment ...                                    0.033301
# Product Insured_Pumps and Motors                                                      0.057817
# Disposition                                                                           0.081876
#
#                                                     Product Insured_Inventory - Raw Material  \
# Claim Amount                                                                        0.006308
# Close Amount                                                                        0.042812
# City Code_AMD                                                                       0.029405
# City Code_ATQ                                                                       0.000273
# City Code_BDQ                                                                       0.004280
# ...                                                                                      ...
# Product Insured_Misc. Lab Equipment                                                 0.080546
# Product Insured_Misc. Sensors                                                       0.073390
# Product Insured_Property, Plant, and Equipment ...                                  0.056620
# Product Insured_Pumps and Motors                                                    0.098304
# Disposition                                                                         0.102056
#
#                                                     Product Insured_Misc. Electrical Equipment  \
# Claim Amount                                                                          0.084010
# Close Amount                                                                          0.059409
# City Code_AMD                                                                         0.002444
# City Code_ATQ                                                                         0.013598
# City Code_BDQ                                                                         0.001670
# ...                                                                                        ...
# Product Insured_Misc. Lab Equipment                                                   0.044333
# Product Insured_Misc. Sensors                                                         0.040395
# Product Insured_Property, Plant, and Equipment ...                                    0.031164
# Product Insured_Pumps and Motors                                                      0.054107
# Disposition                                                                           0.085071
#
#                                                     Product Insured_Misc. Electronic Items  \
# Claim Amount                                                                      0.112017
# Close Amount                                                                      0.097450
# City Code_AMD                                                                     0.016874
# City Code_ATQ                                                                     0.001111
# City Code_BDQ                                                                     0.023785
# ...                                                                                    ...
# Product Insured_Misc. Lab Equipment                                               0.063992
# Product Insured_Misc. Sensors                                                     0.058307
# Product Insured_Property, Plant, and Equipment ...                                0.044983
# Product Insured_Pumps and Motors                                                  0.078100
# Disposition                                                                       0.002986
#
#                                                     Product Insured_Misc. Engineering Tools  \
# Claim Amount                                                                       0.025302
# Close Amount                                                                       0.001689
# City Code_AMD                                                                      0.012951
# City Code_ATQ                                                                      0.000731
# City Code_BDQ                                                                      0.003918
# ...                                                                                     ...
# Product Insured_Misc. Lab Equipment                                                0.054387
# Product Insured_Misc. Sensors                                                      0.049555
# Product Insured_Property, Plant, and Equipment ...                                 0.038231
# Product Insured_Pumps and Motors                                                   0.066377
# Disposition                                                                        0.064073
#
#                                                     Product Insured_Misc. Lab Equipment  \
# Claim Amount                                                                   0.063651
# Close Amount                                                                   0.051034
# City Code_AMD                                                                  0.003369
# City Code_ATQ                                                                  0.000148
# City Code_BDQ                                                                  0.005739
# ...                                                                                 ...
# Product Insured_Misc. Lab Equipment                                            1.000000
# Product Insured_Misc. Sensors                                                  0.018951
# Product Insured_Property, Plant, and Equipment ...                             0.014621
# Product Insured_Pumps and Motors                                               0.025384
# Disposition                                                                    0.022167
#
#                                                     Product Insured_Misc. Sensors  \
# Claim Amount                                                             0.005295
# Close Amount                                                             0.008161
# City Code_AMD                                                            0.004935
# City Code_ATQ                                                            0.001553
# City Code_BDQ                                                            0.009017
# ...                                                                           ...
# Product Insured_Misc. Lab Equipment                                      0.018951
# Product Insured_Misc. Sensors                                            1.000000
# Product Insured_Property, Plant, and Equipment ...                       0.013322
# Product Insured_Pumps and Motors                                         0.023129
# Disposition                                                              0.008731
#
#                                                     Product Insured_Property, Plant, and Equipment (PPE) Parts  \
# Claim Amount                                                                                 0.009255
# Close Amount                                                                                 0.015860
# City Code_AMD                                                                                0.011824
# City Code_ATQ                                                                                0.001914
# City Code_BDQ                                                                                0.002296
# ...                                                                                               ...
# Product Insured_Misc. Lab Equipment                                                          0.014621
# Product Insured_Misc. Sensors                                                                0.013322
# Product Insured_Property, Plant, and Equipment ...                                           1.000000
# Product Insured_Pumps and Motors                                                             0.017844
# Disposition                                                                                  0.004648
#
#                                                     Product Insured_Pumps and Motors  \
# Claim Amount                                                                0.006790
# Close Amount                                                                0.050364
# City Code_AMD                                                               0.003831
# City Code_ATQ                                                               0.000770
# City Code_BDQ                                                               0.004515
# ...                                                                              ...
# Product Insured_Misc. Lab Equipment                                         0.025384
# Product Insured_Misc. Sensors                                               0.023129
# Product Insured_Property, Plant, and Equipment ...                          0.017844
# Product Insured_Pumps and Motors                                            1.000000
# Disposition                                                                 0.036842
#
#                                                     Disposition
# Claim Amount                                           0.022863
# Close Amount                                           0.453405
# City Code_AMD                                          0.043428
# City Code_ATQ                                          0.032968
# City Code_BDQ                                          0.001014
# ...                                                         ...
# Product Insured_Misc. Lab Equipment                    0.022167
# Product Insured_Misc. Sensors                          0.008731
# Product Insured_Property, Plant, and Equipment ...     0.004648
# Product Insured_Pumps and Motors                       0.036842
# Disposition                                            1.000000
#
# [74 rows x 74 columns]

# %%
round(abs(temp_df_2.corr()),2)['Disposition'].sort_values(ascending=False)
# Out:
# Disposition                                            1.00
# Product Insured_Furniture                              0.11
# Product Insured_Inventory - Raw Material               0.10
# Product Insured_Misc. Electrical Equipment             0.09
# Product Insured_Inventory - Finished Goods             0.08
#                                                        ...
# Enterprise Type_Private Ltd. MSME - Small              0.00
# City_Bhopal                                            0.00
# City_Bangalore                                         0.00
# Enterprise Type_Limited Liability Parterneship (LLP)   0.00
# City Code_PAT                                          0.00
# Name: Disposition, Length: 74, dtype: float64

# %%
temp_df_2.columns
# Out:
# Index(['Claim Amount', 'Close Amount', 'Days Difference', 'City Code_AMD',
#        'City Code_ATQ', 'City Code_BDQ', 'City Code_BHO', 'City Code_BLR',
#        'City Code_BOM', 'City Code_CCU', 'City Code_CJB', 'City Code_DEL',
#        'City Code_HYD', 'City Code_IDR', 'City Code_JAI', 'City Code_KNU',
#        'City Code_LKO', 'City Code_MAA', 'City Code_NGP', 'City Code_NSK',
#        'City Code_PAT', 'City Code_PNQ', 'City Code_STV', 'City Code_THN',
#        'City Code_VSK', 'City_Ahmedabad', 'City_Amritsar', 'City_Bangalore',
#        'City_Bhopal', 'City_Chennai', 'City_Coimbatore', 'City_Delhi',
#        'City_Hyderabad', 'City_Indore', 'City_Jaipur', 'City_Kanpur',
#        'City_Kolkata', 'City_Lucknow', 'City_Mumbai', 'City_Nagpur',
#        'City_Nashik', 'City_Patna', 'City_Pune', 'City_Surat', 'City_Thane',
#        'City_Vadodara', 'City_Visakhapatnam',
#        'Enterprise Type_Foreign Subsidary',
#        'Enterprise Type_Joint-Venture Company',
#        'Enterprise Type_Limited Liability Parterneship (LLP)',
#        'Enterprise Type_Non-Profit Organization (NPO)',
#        'Enterprise Type_One Person Company',
#        'Enterprise Type_Partnership Firm',
#        'Enterprise Type_Private Limited Company',
#        'Enterprise Type_Private Ltd. MSME - Medium',
#        'Enterprise Type_Private Ltd. MSME - Micro',
#        'Enterprise Type_Private Ltd. MSME - Small',
#        'Enterprise Type_Public Limited Company',
#        'Enterprise Type_Sole Proprietorship', 'Claim Type_Property Loss',
#        'Claim Site_Other', 'Claim Site_Warehouse', 'Product Insured_Fixtures',
#        'Product Insured_Furniture',
#        'Product Insured_Heating, ventilation, and air conditioning (HVAC) System',
#        'Product Insured_Inventory - Finished Goods',
#        'Product Insured_Inventory - Raw Material',
#        'Product Insured_Misc. Electrical Equipment',
#        'Product Insured_Misc. Electronic Items',
#        'Product Insured_Misc. Engineering Tools',
#        'Product Insured_Misc. Lab Equipment', 'Product Insured_Misc. Sensors',
#        'Product Insured_Property, Plant, and Equipment (PPE) Parts',
#        'Product Insured_Pumps and Motors', 'Disposition'],
#       dtype='object')

# %%
x
# Out:
#       City Code       City             Enterprise Type       Claim Type  \
# 0           NSK     Nashik      Public Limited Company    Property Loss
# 1           BOM     Mumbai          One Person Company    Property Loss
# 2           LKO    Lucknow      Public Limited Company    Property Loss
# 3           DEL      Delhi         Sole Proprietorship    Property Loss
# 4           DEL      Delhi          One Person Company    Property Loss
# ...         ...        ...                         ...              ...
# 34105       AGR       Agra      Public Limited Company    Property Loss
# 34106       LKO    Lucknow            Partnership Firm  Property Damage
# 34107       HYD  Hyderabad          One Person Company  Property Damage
# 34108       MAA    Chennai         Sole Proprietorship  Property Damage
# 34109       LKO    Lucknow  Private Ltd. MSME - Medium    Property Loss
#
#        Claim Site                             Product Insured  Claim Amount  \
# 0      In Transit                    Inventory - Raw Material        490.00
# 1      In Transit  Cameras and other Misc. Security Equipment        300.00
# 2      In Transit                                    Fixtures         83.98
# 3      In Transit                            Pumps and Motors        507.88
# 4      In Transit                     Misc. Engineering Tools         83.46
# ...           ...                                         ...           ...
# 34105  In Transit                     Misc. Engineering Tools        238.00
# 34106  In Transit                      Misc. Electronic Items          7.00
# 34107  In Transit                      Misc. Electronic Items        166.00
# 34108   Warehouse                            Pumps and Motors        450.00
# 34109  In Transit                    Inventory - Raw Material         70.35
#
#        Close Amount
# 0              0.00
# 1            150.00
# 2             83.98
# 3              0.00
# 4             41.73
# ...             ...
# 34105        115.60
# 34106          0.00
# 34107         70.00
# 34108        280.00
# 34109         70.35
#
# [34110 rows x 8 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(temp_df, y, test_size =0.3, stratify = y, random_state=120)

# %%
X_train.isnull().sum().sort_values(ascending=False)
# Out:
# Claim Amount                                  0
# City_Mumbai                                   0
# Enterprise Type_Private Ltd. MSME - Medium    0
# Enterprise Type_Private Limited Company       0
# Enterprise Type_Partnership Firm              0
#                                              ..
# City_Ahmedabad                                0
# City Code_VSK                                 0
# City Code_THN                                 0
# City Code_STV                                 0
# Product Insured_Pumps and Motors              0
# Length: 73, dtype: int64

# %%
# 2. support vector machine
svc = SVC()

# Train Classifer
svc.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = svc.predict(X_test)
sva=accuracy_score(y_test, y_pred)
print("support vector machine Model Accuracy:", sva)
# Out:
# support vector machine Model Accuracy: 0.8310368415909313

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[5275,    0,   79],
#        [1152,  673,  338],
#        [ 159,    1, 2556]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.99      0.88      5354
#            1       1.00      0.31      0.47      2163
#            2       0.86      0.94      0.90      2716
#
#     accuracy                           0.83     10233
#    macro avg       0.89      0.75      0.75     10233
# weighted avg       0.86      0.83      0.80     10233

# %%
import pickle

# %%
with open("svc_model.pkl", 'wb') as model_file:
    pickle.dump(svc, model_file)

# %%
with open("svc_model.pkl", "rb") as infile:
    svc_model = pickle.load(infile)

# %%
x.columns.tolist()
# Out:
# ['City Code',
#  'City',
#  'Enterprise Type',
#  'Claim Type',
#  'Claim Site',
#  'Product Insured',
#  'Claim Amount',
#  'Close Amount']

# %%
# !pip install lazypredict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: lightgbm in /usr/share/anaconda3/lib/python3.9/site-packages (from lazypredict) (3.3.3)
# Requirement already satisfied: joblib in /usr/share/anaconda3/lib/python3.9/site-packages (from lazypredict) (1.1.0)
# Requirement already satisfied: pandas in /usr/share/anaconda3/lib/python3.9/site-packages (from lazypredict) (1.4.4)
# Requirement already satisfied: scikit-learn in /usr/share/anaconda3/lib/python3.9/site-packages (from lazypredict) (1.1.3)
# Requirement already satisfied: click in /usr/share/anaconda3/lib/python3.9/site-packages (from lazypredict) (8.0.4)
# Requirement already satisfied: xgboost in /usr/share/anaconda3/lib/python3.9/site-packages (from lazypredict) (1.7.1)
# Requirement already satisfied: tqdm in /usr/share/anaconda3/lib/python3.9/site-packages (from lazypredict) (4.64.1)
# Requirement already satisfied: wheel in /usr/share/anaconda3/lib/python3.9/site-packages (from lightgbm->lazypredict) (0.37.1)
# Requirement already satisfied: scipy in /home/kushagrav/.local/lib/python3.9/site-packages (from lightgbm->lazypredict) (1.9.3)
# Requirement already satisfied: numpy in /usr/share/anaconda3/lib/python3.9/site-packages (from lightgbm->lazypredict) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/share/anaconda3/lib/python3.9/site-packages (from scikit-learn->lazypredict) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/share/anaconda3/lib/python3.9/site-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/kushagrav/.local/lib/python3.9/site-packages (from pandas->lazypredict) (2022.7)
# Requirement already satisfied: six>=1.5 in /usr/share/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)
# Installing collected packages: lazypredict
#   WARNING: The script lazypredict is installed in '/home/kushagrav/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed lazypredict-0.2.12

# %%
from lazypredict.Supervised import LazyClassifier
temp_model = LazyClassifier()

# %%
temp_model.fit(X_train ,X_test,y_train, y_test)
# Out:
#   7%|▋         | 2/29 [00:01<00:17,  1.58it/s]/usr/share/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/share/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/share/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/share/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/share/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
#  38%|███▊      | 11/29 [00:48<00:48,  2.71s/it]/usr/share/anaconda3/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#  41%|████▏     | 12/29 [00:54<00:56,  3.32s/it]/usr/share/anaconda3/lib/python3.9/site-packages/sklearn/semi_supervised/_label_propagation.py:222: RuntimeWarning: invalid value encountered in true_divide
#   probabilities /= normalizer
#  48%|████▊     | 14/29 [01:02<00:50,  3.39s/it]/usr/share/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
#  52%|█████▏    | 15/29 [01:13<01:17,  5.56s/it]/usr/share/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  69%|██████▉   | 20/29 [02:02<01:06,  7.44s/it]/usr/share/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# 100%|██████████| 29/29 [02:48<00:00,  5.79s/it]
# (                               Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
#  Model
#  XGBClassifier                      0.99               0.99    None      0.99
#  LGBMClassifier                     0.98               0.98    None      0.98
#  BaggingClassifier                  0.98               0.98    None      0.98
#  DecisionTreeClassifier             0.97               0.97    None      0.97
#  RandomForestClassifier             0.92               0.92    None      0.92
#  AdaBoostClassifier                 0.90               0.90    None      0.90
#  LogisticRegression                 0.80               0.80    None      0.79
#  LinearSVC                          0.75               0.75    None      0.75
#  ExtraTreesClassifier               0.75               0.75    None      0.75
#  SGDClassifier                      0.73               0.73    None      0.73
#  CalibratedClassifierCV             0.66               0.66    None      0.66
#  NuSVC                              0.65               0.65    None      0.64
#  ExtraTreeClassifier                0.64               0.64    None      0.64
#  Perceptron                         0.62               0.62    None      0.62
#  SVC                                0.60               0.60    None      0.60
#  PassiveAggressiveClassifier        0.57               0.57    None      0.56
#  BernoulliNB                        0.54               0.54    None      0.54
#  LabelPropagation                   0.53               0.53    None      0.53
#  LabelSpreading                     0.53               0.53    None      0.53
#  LinearDiscriminantAnalysis         0.52               0.52    None      0.52
#  RidgeClassifier                    0.52               0.52    None      0.51
#  RidgeClassifierCV                  0.52               0.52    None      0.51
#  KNeighborsClassifier               0.51               0.51    None      0.50
#  NearestCentroid                    0.50               0.50    None      0.50
#  GaussianNB                         0.46               0.46    None      0.45
#  QuadraticDiscriminantAnalysis      0.36               0.36    None      0.32
#  DummyClassifier                    0.33               0.33    None      0.17
#
#                                 Time Taken
#  Model
#  XGBClassifier                        3.37
#  LGBMClassifier                       1.70
#  BaggingClassifier                    0.51
#  DecisionTreeClassifier               0.14
#  RandomForestClassifier               1.66
#  AdaBoostClassifier                   0.80
#  LogisticRegression                   0.43
#  LinearSVC                           11.39
#  ExtraTreesClassifier                 2.45
#  SGDClassifier                        0.87
#  CalibratedClassifierCV              44.38
#  NuSVC                               47.73
#  ExtraTreeClassifier                  0.06
#  Perceptron                           0.34
#  SVC                                 37.29
#  PassiveAggressiveClassifier          0.36
#  BernoulliNB                          0.06
#  LabelPropagation                     5.35
#  LabelSpreading                       7.96
#  LinearDiscriminantAnalysis           0.35
#  RidgeClassifier                      0.07
#  RidgeClassifierCV                    0.09
#  KNeighborsClassifier                 0.39
#  NearestCentroid                      0.06
#  GaussianNB                           0.06
#  QuadraticDiscriminantAnalysis        0.09
#  DummyClassifier                      0.04  ,
#                                 Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
#  Model
#  XGBClassifier                      0.99               0.99    None      0.99
#  LGBMClassifier                     0.98               0.98    None      0.98
#  BaggingClassifier                  0.98               0.98    None      0.98
#  DecisionTreeClassifier             0.97               0.97    None      0.97
#  RandomForestClassifier             0.92               0.92    None      0.92
#  AdaBoostClassifier                 0.90               0.90    None      0.90
#  LogisticRegression                 0.80               0.80    None      0.79
#  LinearSVC                          0.75               0.75    None      0.75
#  ExtraTreesClassifier               0.75               0.75    None      0.75
#  SGDClassifier                      0.73               0.73    None      0.73
#  CalibratedClassifierCV             0.66               0.66    None      0.66
#  NuSVC                              0.65               0.65    None      0.64
#  ExtraTreeClassifier                0.64               0.64    None      0.64
#  Perceptron                         0.62               0.62    None      0.62
#  SVC                                0.60               0.60    None      0.60
#  PassiveAggressiveClassifier        0.57               0.57    None      0.56
#  BernoulliNB                        0.54               0.54    None      0.54
#  LabelPropagation                   0.53               0.53    None      0.53
#  LabelSpreading                     0.53               0.53    None      0.53
#  LinearDiscriminantAnalysis         0.52               0.52    None      0.52
#  RidgeClassifier                    0.52               0.52    None      0.51
#  RidgeClassifierCV                  0.52               0.52    None      0.51
#  KNeighborsClassifier               0.51               0.51    None      0.50
#  NearestCentroid                    0.50               0.50    None      0.50
#  GaussianNB                         0.46               0.46    None      0.45
#  QuadraticDiscriminantAnalysis      0.36               0.36    None      0.32
#  DummyClassifier                    0.33               0.33    None      0.17
#
#                                 Time Taken
#  Model
#  XGBClassifier                        3.37
#  LGBMClassifier                       1.70
#  BaggingClassifier                    0.51
#  DecisionTreeClassifier               0.14
#  RandomForestClassifier               1.66
#  AdaBoostClassifier                   0.80
#  LogisticRegression                   0.43
#  LinearSVC                           11.39
#  ExtraTreesClassifier                 2.45
#  SGDClassifier                        0.87
#  CalibratedClassifierCV              44.38
#  NuSVC                               47.73
#  ExtraTreeClassifier                  0.06
#  Perceptron                           0.34
#  SVC                                 37.29
#  PassiveAggressiveClassifier          0.36
#  BernoulliNB                          0.06
#  LabelPropagation                     5.35
#  LabelSpreading                       7.96
#  LinearDiscriminantAnalysis           0.35
#  RidgeClassifier                      0.07
#  RidgeClassifierCV                    0.09
#  KNeighborsClassifier                 0.39
#  NearestCentroid                      0.06
#  GaussianNB                           0.06
#  QuadraticDiscriminantAnalysis        0.09
#  DummyClassifier                      0.04  )

# %%
# 2. XGBoost
XGB = XGBClassifier()

# Train Classifer
XGB.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = XGB.predict(X_test)
xga=accuracy_score(y_test, y_pred)
print("support vector machine Model Accuracy:", xga)
# Out:
# support vector machine Model Accuracy: 0.9853598397287717

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2163
#            1       0.99      0.98      0.98      2163
#            2       0.97      0.99      0.98      2163
#
#     accuracy                           0.99      6489
#    macro avg       0.99      0.99      0.99      6489
# weighted avg       0.99      0.99      0.99      6489

# %%
models = {"KNN":KNeighborsClassifier(),
          "Deciion Tree": DecisionTreeClassifier(),
          "SVC":SVC(),
          "Logistic Regresion": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
          "Adaboost": AdaBoostClassifier(),
          "Gradient Boosting": GradientBoostingClassifier()}
